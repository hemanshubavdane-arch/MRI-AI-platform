# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\mri_dl_proj\tfenv\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (3.13.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (2.4.1)
# Requirement already satisfied: h5py>=3.11.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\mri_dl_proj\tfenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\mri_dl_proj\tfenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\mri_dl_proj\tfenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\mri_dl_proj\tfenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\mri_dl_proj\tfenv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\mri_dl_proj\tfenv\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\mri_dl_proj\tfenv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\mri_dl_proj\tfenv\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\mri_dl_proj\tfenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\mri_dl_proj\tfenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\mri_dl_proj\tfenv\lib\site-packages (3.13.1)
# Requirement already satisfied: absl-py in c:\mri_dl_proj\tfenv\lib\site-packages (from keras) (2.3.1)
# Requirement already satisfied: numpy in c:\mri_dl_proj\tfenv\lib\site-packages (from keras) (2.4.1)
# Requirement already satisfied: rich in c:\mri_dl_proj\tfenv\lib\site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in c:\mri_dl_proj\tfenv\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\mri_dl_proj\tfenv\lib\site-packages (from keras) (3.15.1)
# Requirement already satisfied: optree in c:\mri_dl_proj\tfenv\lib\site-packages (from keras) (0.18.0)
# Requirement already satisfied: ml-dtypes in c:\mri_dl_proj\tfenv\lib\site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in c:\mri_dl_proj\tfenv\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\mri_dl_proj\tfenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

# %%
from tensorflow.keras import layers, models

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\mri_dl_proj\tfenv\lib\site-packages (4.13.0.90)
# Requirement already satisfied: numpy>=2 in c:\mri_dl_proj\tfenv\lib\site-packages (from opencv-python) (2.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flask
# Out:
# Requirement already satisfied: flask in c:\mri_dl_proj\tfenv\lib\site-packages (3.1.2)
# Requirement already satisfied: blinker>=1.9.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\mri_dl_proj\tfenv\lib\site-packages (from flask) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\mri_dl_proj\tfenv\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\mri_dl_proj\tfenv\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\mri_dl_proj\tfenv\lib\site-packages (from flask) (3.1.5)
# Requirement already satisfied: colorama in c:\mri_dl_proj\tfenv\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\mri_dl_proj\tfenv\lib\site-packages (12.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gunicorn
# Out:
# Requirement already satisfied: gunicorn in c:\mri_dl_proj\tfenv\lib\site-packages (23.0.0)
# Requirement already satisfied: packaging in c:\mri_dl_proj\tfenv\lib\site-packages (from gunicorn) (25.0)
# Note: you may need to restart the kernel to use updated packages.
